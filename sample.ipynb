# %% [markdown]
# <a href="https://colab.research.google.com/github/neelamizhi/e/blob/main/sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (87)
# Out:
# 87

# %%
a = 3
b = 32
c=a+b

print("sum is",c)
# Out:
# sum is 35
